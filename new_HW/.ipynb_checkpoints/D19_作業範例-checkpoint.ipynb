# %% [markdown]
# 範例目標:<br>
# 1. 實做繪製圖表
# 2. 藉由圖表對資料有初步認識，並解釋圖表意義

# %% [markdown]
# 範例重點:<br>
# 1. 每一種圖表都有相對應用的情境，分辨情境並繪製對應圖表
# 2. 圖像化展現，方便對於資料有初步的理解

# %%
import pandas as pd
import numpy as np

# %%
#單一折線圖
ts = pd.Series(np.random.randn(200), index=pd.date_range('1/1/2020', periods=200))
ts = ts.cumsum()
print(ts)
ts.plot()
# Out:
# 2020-01-01    0.572491
# 2020-01-02    0.237394
# 2020-01-03    0.116482
# 2020-01-04    1.128662
# 2020-01-05    0.387111
#                 ...
# 2020-07-14   -6.359765
# 2020-07-15   -5.357197
# 2020-07-16   -3.742714
# 2020-07-17   -3.084158
# 2020-07-18   -2.218696
# Freq: D, Length: 200, dtype: float64

# %%
#多個折線圖同時畫出
df = pd.DataFrame(np.random.randn(200, 3), index=pd.date_range('1/1/2020', periods=200), columns=["A","B","C"])
df = df.cumsum()
print(df)
df.plot();
# Out:
#                     A          B         C
# 2020-01-01   1.638028  -1.217120  0.151052
# 2020-01-02   1.554679  -1.646553  0.265816
# 2020-01-03   1.904248  -1.223552 -0.545570
# 2020-01-04   2.359738  -2.322124  0.490419
# 2020-01-05   2.824292  -2.500203 -0.900321
# ...               ...        ...       ...
# 2020-07-14  17.757031   8.873837  2.794589
# 2020-07-15  18.243133   9.997317  2.150779
# 2020-07-16  16.293618  10.588068  1.137530
# 2020-07-17  15.943101  10.984044  2.812564
# 2020-07-18  13.540884  10.493363  2.356788
#
# [200 rows x 3 columns]

# %%
#圓餅圖
df = pd.Series(np.random.rand(4), index=["A","B","C","D"],name="title")
print(df)
df.plot.pie()
# Out:
# A    0.082827
# B    0.194399
# C    0.972521
# D    0.773414
# Name: title, dtype: float64

# %%
#長條圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.plot.bar();
# Out:
#           A         B
# 0  0.266093  0.702423
# 1  0.529459  0.104959
# 2  0.515524  0.929081
# 3  0.693186  0.766644
# 4  0.473430  0.093004
# 5  0.145382  0.333179
# 6  0.955821  0.749531
# 7  0.818538  0.254093
# 8  0.319553  0.294517
# 9  0.463244  0.118817

# %%
df.plot.bar(stacked=True);

# %%
#箱型圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.boxplot()
# Out:
#           A         B
# 0  0.010652  0.823911
# 1  0.513423  0.709575
# 2  0.339515  0.490098
# 3  0.909224  0.498394
# 4  0.890131  0.028865
# 5  0.554147  0.531304
# 6  0.171770  0.472194
# 7  0.716334  0.099767
# 8  0.348857  0.524795
# 9  0.081672  0.868000

# %%
#散佈圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.plot.scatter(x='A', y='B')
# Out:
#           A         B
# 0  0.421692  0.177029
# 1  0.724267  0.119460
# 2  0.783900  0.863117
# 3  0.690839  0.705001
# 4  0.620353  0.511348
# 5  0.898797  0.029353
# 6  0.906124  0.971339
# 7  0.589882  0.805320
# 8  0.756088  0.681251
# 9  0.640762  0.473928
