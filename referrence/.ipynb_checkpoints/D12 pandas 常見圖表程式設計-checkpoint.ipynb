# %% [markdown]
# 範例目標:<br>
# 1. 實做繪製圖表
# 2. 藉由圖表對資料有初步認識，並解釋圖表意義

# %% [markdown]
# 範例重點:<br>
# 1. 每一種圖表都有相對應用的情境，分辨情境並繪製對應圖表
# 2. 圖像化展現，方便對於資料有初步的理解

# %%
import pandas as pd
import numpy as np

# %%
#單一折線圖
ts = pd.Series(np.random.randn(200), index=pd.date_range('1/1/2020', periods=200))
ts = ts.cumsum()
print(ts)
ts.plot()
# Out:
# 2020-01-01    1.232319
# 2020-01-02    1.976596
# 2020-01-03    1.193412
# 2020-01-04    1.501582
# 2020-01-05    0.346346
#                 ...
# 2020-07-14    6.647221
# 2020-07-15    7.253827
# 2020-07-16    7.662437
# 2020-07-17    9.088210
# 2020-07-18    8.587510
# Freq: D, Length: 200, dtype: float64

# %%
#多個折線圖同時畫出
df = pd.DataFrame(np.random.randn(200, 3), index=pd.date_range('1/1/2020', periods=200), columns=["A","B","C"])
df = df.cumsum()
print(df)
df.plot();
# Out:
#                     A          B         C
# 2020-01-01  -0.153188  -0.728056 -0.333691
# 2020-01-02  -0.503599  -1.830957 -0.270276
# 2020-01-03  -0.110339  -1.296366  1.464115
# 2020-01-04  -2.309529  -1.611648  0.191914
# 2020-01-05  -0.736532  -1.180177  0.310736
# ...               ...        ...       ...
# 2020-07-14 -28.455086  12.325483 -5.907159
# 2020-07-15 -27.799805  12.484363 -5.178265
# 2020-07-16 -27.174162  11.654452 -4.304190
# 2020-07-17 -27.946205  11.551620 -4.085539
# 2020-07-18 -28.284834  12.288600 -4.033301
#
# [200 rows x 3 columns]

# %%
#圓餅圖
df = pd.Series(np.random.rand(4), index=["A","B","C","D"],name="title")
print(df)
df.plot.pie()
# Out:
# A    0.907079
# B    0.880492
# C    0.821091
# D    0.951724
# Name: title, dtype: float64

# %%
#長條圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.plot.bar();
# Out:
#           A         B
# 0  0.493800  0.984589
# 1  0.312160  0.259790
# 2  0.322494  0.696398
# 3  0.259572  0.271661
# 4  0.830622  0.235203
# 5  0.150645  0.633931
# 6  0.262581  0.366315
# 7  0.717116  0.759940
# 8  0.899328  0.398963
# 9  0.479488  0.032729

# %%
df.plot.bar(stacked=True);

# %%
#箱型圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.boxplot()
# Out:
#           A         B
# 0  0.750377  0.506559
# 1  0.456302  0.047247
# 2  0.389991  0.053468
# 3  0.591573  0.322805
# 4  0.167653  0.797321
# 5  0.578157  0.715799
# 6  0.921782  0.077834
# 7  0.747871  0.715213
# 8  0.050406  0.243939
# 9  0.755980  0.050495

# %%
#散佈圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.plot.scatter(x='A', y='B')
# Out:
#           A         B
# 0  0.904101  0.453691
# 1  0.001502  0.582882
# 2  0.472227  0.333484
# 3  0.509957  0.320143
# 4  0.894529  0.806347
# 5  0.352787  0.233408
# 6  0.181226  0.306082
# 7  0.667289  0.363010
# 8  0.923582  0.097958
# 9  0.688632  0.518275
